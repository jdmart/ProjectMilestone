# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# %%
N = 4000

# %%
x = np.random.random(size=N)*100
y = np.random.random(size=N)*100
radii = np.random.random(size=N)*1.5
colors = ["#%02x%02x%02x" % (int(r),int(g),150) for r, g in zip(np.floor(50+2*x), np.floor(30+2*y))]

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
p = figure()
p.circle(x, y, radius=radii, fill_color=colors, fill_alpha=0.6, line_color=None)
# Out:
# GlyphRenderer(id='1039', ...)

# %%
show(p)
# Out:
#   <div class="bk-root" id="faa7e45a-fd21-420d-986a-c4f14fb49da0" data-root-id="1002"></div>

# %%
x = np.linspace(1,10,10)
y = 2*x
p2 = figure()
p2.line(x,y)
show(p2)
# Out:
#   <div class="bk-root" id="f0330134-1723-454c-bc00-8d4d0f0b7e7c" data-root-id="1725"></div>
